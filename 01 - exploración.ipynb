# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importa el dataset train.csv
data = pd.read_csv('train.csv')
data.head(1)
# Out:
#        ID  PERIODO ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212          ENFERMERIA                 BOGOTÁ
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET               FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                 Si  Técnica o tecnológica incompleta
#
#   FAMI_TIENELAVADORA  ... ESTU_PRIVADO_LIBERTAD ESTU_PAGOMATRICULAPROPIO  \
# 0                 Si  ...                     N                       No
#
#   FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET.1 FAMI_EDUCACIONMADRE  \
# 0                   Si                   Si           Postgrado
#
#   RENDIMIENTO_GLOBAL coef_1  coef_2  coef_3  coef_4
# 0         medio-alto  0.322   0.208    0.31   0.267
#
# [1 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              692500 non-null  int64
#  1   PERIODO                         692500 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         661643 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            660363 non-null  object
#  7   FAMI_TIENEINTERNET              665871 non-null  object
#  8   FAMI_EDUCACIONPADRE             669322 non-null  object
#  9   FAMI_TIENELAVADORA              652727 non-null  object
#  10  FAMI_TIENEAUTOMOVIL             648877 non-null  object
#  11  ESTU_PRIVADO_LIBERTAD           692500 non-null  object
# ...

# %%
counts = data['ESTU_PRGM_DEPARTAMENTO'].value_counts()

ax = counts.plot(kind='bar')
plt.title('Número de estudiantes por departamento')
plt.ylabel('Cantidad de estudiantes')
plt.xlabel('Departamento')

# Ajustar el límite del eje Y (10% más alto que el máximo)
plt.ylim(0, counts.max() * 1.1)

for i, value in enumerate(counts):
    plt.text(i, value + 0.5, str(value),
             ha='center', va='bottom',
             rotation=90, fontsize=6)

plt.show()

# %%
programa = input("Ingrese el nombre del programa académico que desea consultar: ")

# Contar cuántos estudiantes hay en ese programa
conteo = data['ESTU_PRGM_ACADEMICO'].value_counts().get(programa, 0)

# Mostrar el resultado
if conteo > 0:
    print(f"El programa '{programa}' tiene {conteo} estudiantes.")
else:
    print(f"No se encontraron estudiantes en el programa '{programa}'.")
# Out:
# El programa 'ENFERMERÍA' tiene 551 estudiantes.
